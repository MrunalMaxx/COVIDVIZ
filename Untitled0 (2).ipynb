# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import warnings
import glob
import os

warnings.filterwarnings('ignore')

# %%
import plotly.io as pio

# %%
df_Covid = pd.read_csv("/content/drive/MyDrive/covid_19_data.csv") 
df_Covid = df_Covid[0:191494]

# %%
#!pip install streamlit

# %% [markdown]
# # New Section

# %%
# !pip install chart_studio
import chart_studio
# Out:
# ...
#      |████████████████████████████████| 71kB 3.2MB/s
# ...

# %%
df_Covid.head()
df_Covid.tail()
# Out:
#            SNo ObservationDate     Province/State  ... Confirmed  Deaths  Recovered
# 191489  191490      12/31/2020  Zaporizhia Oblast  ...   54088.0   594.0    20530.0
# 191490  191491      12/31/2020            Zeeland  ...   10462.0   127.0        0.0
# 191491  191492      12/31/2020           Zhejiang  ...    1306.0     1.0     1293.0
# 191492  191493      12/31/2020    Zhytomyr Oblast  ...   39202.0   655.0    31998.0
# 191493  191494      12/31/2020       Zuid-Holland  ...  202237.0  2820.0        0.0
#
# [5 rows x 8 columns]

# %%
df_Covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191494 entries, 0 to 191493
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              191494 non-null  int64
#  1   ObservationDate  191494 non-null  object
#  2   Province/State   139347 non-null  object
#  3   Country/Region   191494 non-null  object
#  4   Last Update      191494 non-null  object
#  5   Confirmed        191494 non-null  float64
#  6   Deaths           191494 non-null  float64
#  7   Recovered        191494 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 11.7+ MB

# %%
def plot_worldmap(df, location, time, color, title):
    fig = px.choropleth(df, 
                        locations=location,
                        locationmode = "country names",
                        color=color, 
                        hover_name=location, 
                        animation_frame=time
                       )
    fig.update_layout(title_text = title,
                      title_x = 0.5,
                      geo=dict(
                      showframe = False,
                      showcoastlines = False)
                    )
    fig.show()
    return(fig)

# %%
new = df_Covid["ObservationDate"].str.split("/", n = 1, expand = True) 
df_Covid["month"] = new[0]

# %%
df_Covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191494 entries, 0 to 191493
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              191494 non-null  int64
#  1   ObservationDate  191494 non-null  object
#  2   Province/State   139347 non-null  object
#  3   Country/Region   191494 non-null  object
#  4   Last Update      191494 non-null  object
#  5   Confirmed        191494 non-null  float64
#  6   Deaths           191494 non-null  float64
#  7   Recovered        191494 non-null  float64
#  8   month            191494 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 13.1+ MB

# %%
df_Covid.rename(columns={'Country/Region': 'country'}, inplace=True)
df_Covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191494 entries, 0 to 191493
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              191494 non-null  int64
#  1   ObservationDate  191494 non-null  object
#  2   Province/State   139347 non-null  object
#  3   country          191494 non-null  object
#  4   Last Update      191494 non-null  object
#  5   Confirmed        191494 non-null  float64
#  6   Deaths           191494 non-null  float64
#  7   Recovered        191494 non-null  float64
#  8   month            191494 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 13.1+ MB

# %%
#plot_worldmap(df, 'country', 'month', 'Confirmed', 'Life Expectancy at Birth (years)')

# %%
df2 = df_Covid
df2.ObservationDate = pd.to_datetime(df2['ObservationDate'])
df2['YearMonth'] = df2.ObservationDate.dt.to_period("M")

df_groupby_confo = df2[['Confirmed','country','month']].groupby(by=[df2.month, df2['country']]).sum().reset_index()

df_groupby_Deaths = df2[['Deaths','country','month']].groupby(by=[df2.month, df2['country']]).sum().reset_index()

df_groupby_Recovered = df2[['Recovered','country','month']].groupby(by=[df2.month, df2['country']]).sum().reset_index()

# %%
df_groupby_confo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      2026 non-null   object
#  1   country    2026 non-null   object
#  2   Confirmed  2026 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 47.6+ KB

# %%
df_groupby_Deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   month    2026 non-null   object
#  1   country  2026 non-null   object
#  2   Deaths   2026 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 47.6+ KB

# %%
df_groupby_confo
# Out:
#      month             country  Confirmed
# 0       01           Australia       41.0
# 1       01              Brazil        0.0
# 2       01            Cambodia        5.0
# 3       01              Canada       12.0
# 4       01            Colombia        0.0
# ...    ...                 ...        ...
# 2021    12             Vietnam    43541.0
# 2022    12  West Bank and Gaza  3560267.0
# 2023    12               Yemen    64649.0
# 2024    12              Zambia   579474.0
# 2025    12            Zimbabwe   366341.0
#
# [2026 rows x 3 columns]

# %%
fig_confo = plot_worldmap(df_groupby_confo, 'country', 'month', 'Confirmed', 'Covid Confirmed Number of Cases in 2020')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="04c1aedb-2583-4c56-8cd2-c08a68d907dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04c1aedb-2583-4c56-8cd2-c08a68d907dc")) {
#                     Plotly.newPlot(
#                         '04c1aedb-2583-4c56-8cd2-c08a68d907dc',
# ...

# %%
username = 'mrunal66' # your username
api_key = '3zJwUbwOWoiInGEmZKjk' # your api key - go to profile > settings > regenerate key
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
import chart_studio.plotly as py
py.plot(fig_confo, filename = 'Covid_Confirmed_Viz', auto_open=True)
# Out:
# 'https://plotly.com/~mrunal66/1/'

# %%
fig_deaths = plot_worldmap(df_groupby_Deaths, 'country', 'month', 'Deaths', 'Covid Deaths Monthly Stats in 2020')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7f9c7256-ced3-48d7-830d-126ee62be0db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7f9c7256-ced3-48d7-830d-126ee62be0db")) {
#                     Plotly.newPlot(
#                         '7f9c7256-ced3-48d7-830d-126ee62be0db',
# ...

# %%
fig_recover = plot_worldmap(df_groupby_Recovered, 'country', 'month', 'Recovered', 'Covid Recovered Number of Cases in 2020 Monthly Stats')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d86e38a-4213-466b-b0da-799a2e733315" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d86e38a-4213-466b-b0da-799a2e733315")) {
#                     Plotly.newPlot(
#                         '4d86e38a-4213-466b-b0da-799a2e733315',
# ...

# %%
py.plot(fig_deaths, filename = 'Covid_Deaths_Viz', auto_open=True)
# Out:
# 'https://plotly.com/~mrunal66/3/'

# %%
py.plot(fig_recover, filename = 'Covid_Recover_Viz', auto_open=True)
# Out:
# 'https://plotly.com/~mrunal66/5/'
